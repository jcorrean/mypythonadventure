# %%
import pandas as pd

# %%
pave = pd.read_csv("/home/juan/Documents/Datos1.csv")

# %%
pave
# Out:
#     Notas       Curso
# 0      63      Online
# 1      57      Online
# 2      56      Online
# 3      63      Online
# 4      63      Online
# 5      62      Online
# 6      59      Online
# 7      62      Online
# 8      61      Online
# 9      58      Online
# 10     52      Online
# 11     50      Online
# 12     50      Online
# 13     48      Online
# 14     52      Online
# 15     64      Online
# 16     60      Online
# 17     53      Online
# 18     60      Online
# 19     57      Online
# 20     54      Online
# 21     48      Online
# 22     56      Online
# 23     62      Online
# 24     49      Online
# 25     65      Online
# 26     64      Online
# 27     57      Online
# 28     61      Online
# 29     65  Presencial
# 30     72  Presencial
# 31     74  Presencial
# 32     74  Presencial
# 33     65  Presencial
# 34     68  Presencial
# 35     67  Presencial
# 36     67  Presencial
# 37     75  Presencial
# 38     72  Presencial
# 39     72  Presencial
# 40     74  Presencial
# 41     61  Presencial
# 42     71  Presencial
# 43     71  Presencial
# 44     70  Presencial
# 45     75  Presencial
# 46     64  Presencial
# 47     69  Presencial
# 48     64  Presencial
# 49     74  Presencial
# 50     69  Presencial
# 51     62  Presencial
# 52     67  Presencial
# 53     70  Presencial
# 54     62  Presencial
# 55     72  Presencial
# 56     70  Presencial
# 57     64  Presencial
# 58     66  Presencial
# 59     71  Presencial

# %%
pave.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Notas   60 non-null     int64
#  1   Curso   60 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB

# %%
pave[['Notas']].describe()
# Out:
#            Notas
# count  60.000000
# mean   63.383333
# std     7.463111
# min    48.000000
# 25%    58.750000
# 50%    64.000000
# 75%    70.000000
# max    75.000000

# %%
pave[['Curso', 'Notas']].groupby('Curso').mean()
# Out:
#                 Notas
# Curso
# Online      57.448276
# Presencial  68.935484

# %%
pave.describe()
# Out:
#            Notas
# count  60.000000
# mean   63.383333
# std     7.463111
# min    48.000000
# 25%    58.750000
# 50%    64.000000
# 75%    70.000000
# max    75.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))


# Load the example planets dataset

# Plot the orbital period with horizontal boxes
sns.boxplot(x="Curso", y="Notas", data=pave,
            whis=[0, 100], width=.6, palette="vlag")
# Out:
# <AxesSubplot:xlabel='Curso', ylabel='Notas'>
